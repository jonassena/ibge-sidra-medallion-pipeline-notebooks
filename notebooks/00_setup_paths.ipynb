# %%
# Setup: criar schema para as camadas Medalhão (sem DBFS)

spark.sql("CREATE CATALOG IF NOT EXISTS main")
spark.sql("CREATE SCHEMA IF NOT EXISTS main.medallion")

spark.sql("SHOW SCHEMAS IN main").show(truncate=False)

# %%
# Setup: criar schema para as camadas Medalhão (sem DBFS)

spark.sql("CREATE CATALOG IF NOT EXISTS main")
spark.sql("CREATE SCHEMA IF NOT EXISTS main.medallion")

spark.sql("SHOW SCHEMAS IN main").show(truncate=False)
